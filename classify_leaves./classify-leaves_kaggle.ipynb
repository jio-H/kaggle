# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/classify-leaves/sample_submission.csv
# /kaggle/input/classify-leaves/train.csv
# /kaggle/input/classify-leaves/test.csv
# /kaggle/input/classify-leaves/images/19812.jpg
# /kaggle/input/classify-leaves/images/22735.jpg
# /kaggle/input/classify-leaves/images/16916.jpg
# /kaggle/input/classify-leaves/images/7981.jpg
# /kaggle/input/classify-leaves/images/22706.jpg
# /kaggle/input/classify-leaves/images/20513.jpg
# /kaggle/input/classify-leaves/images/12666.jpg
# /kaggle/input/classify-leaves/images/13288.jpg
# /kaggle/input/classify-leaves/images/20088.jpg
# /kaggle/input/classify-leaves/images/6234.jpg
# /kaggle/input/classify-leaves/images/1269.jpg
# /kaggle/input/classify-leaves/images/22288.jpg
# /kaggle/input/classify-leaves/images/24819.jpg
# /kaggle/input/classify-leaves/images/3863.jpg
# /kaggle/input/classify-leaves/images/6241.jpg
# /kaggle/input/classify-leaves/images/25540.jpg
# /kaggle/input/classify-leaves/images/20529.jpg
# /kaggle/input/classify-leaves/images/10304.jpg
# /kaggle/input/classify-leaves/images/623.jpg
# /kaggle/input/classify-leaves/images/2193.jpg
# /kaggle/input/classify-leaves/images/14143.jpg
# /kaggle/input/classify-leaves/images/11925.jpg
# /kaggle/input/classify-leaves/images/21440.jpg
# /kaggle/input/classify-leaves/images/3750.jpg
# /kaggle/input/classify-leaves/images/11378.jpg
# /kaggle/input/classify-leaves/images/2008.jpg
# /kaggle/input/classify-leaves/images/10730.jpg
# /kaggle/input/classify-leaves/images/17338.jpg
# /kaggle/input/classify-leaves/images/22608.jpg
# /kaggle/input/classify-leaves/images/16730.jpg
# /kaggle/input/classify-leaves/images/5982.jpg
# /kaggle/input/classify-leaves/images/24201.jpg
# /kaggle/input/classify-leaves/images/7737.jpg
# /kaggle/input/classify-leaves/images/26556.jpg
# /kaggle/input/classify-leaves/images/2081.jpg
# /kaggle/input/classify-leaves/images/26645.jpg
# /kaggle/input/classify-leaves/images/14986.jpg
# /kaggle/input/classify-leaves/images/23407.jpg
# /kaggle/input/classify-leaves/images/10597.jpg
# /kaggle/input/classify-leaves/images/19299.jpg
# /kaggle/input/classify-leaves/images/6588.jpg
# /kaggle/input/classify-leaves/images/10054.jpg
# /kaggle/input/classify-leaves/images/12992.jpg
# /kaggle/input/classify-leaves/images/7966.jpg
# /kaggle/input/classify-leaves/images/23149.jpg
# /kaggle/input/classify-leaves/images/3919.jpg
# /kaggle/input/classify-leaves/images/6197.jpg
# /kaggle/input/classify-leaves/images/10924.jpg
# /kaggle/input/classify-leaves/images/15653.jpg
# /kaggle/input/classify-leaves/images/21494.jpg
# /kaggle/input/classify-leaves/images/24752.jpg
# /kaggle/input/classify-leaves/images/20777.jpg
# /kaggle/input/classify-leaves/images/21838.jpg
# /kaggle/input/classify-leaves/images/6399.jpg
# /kaggle/input/classify-leaves/images/25184.jpg
# /kaggle/input/classify-leaves/images/9960.jpg
# /kaggle/input/classify-leaves/images/26076.jpg
# /kaggle/input/classify-leaves/images/27053.jpg
# /kaggle/input/classify-leaves/images/13201.jpg
# /kaggle/input/classify-leaves/images/3757.jpg
# /kaggle/input/classify-leaves/images/9131.jpg
# /kaggle/input/classify-leaves/images/19798.jpg
# /kaggle/input/classify-leaves/images/13856.jpg
# /kaggle/input/classify-leaves/images/26072.jpg
# /kaggle/input/classify-leaves/images/9620.jpg
# /kaggle/input/classify-leaves/images/9062.jpg
# /kaggle/input/classify-leaves/images/4489.jpg
# /kaggle/input/classify-leaves/images/3138.jpg
# /kaggle/input/classify-leaves/images/10213.jpg
# /kaggle/input/classify-leaves/images/3417.jpg
# /kaggle/input/classify-leaves/images/6074.jpg
# /kaggle/input/classify-leaves/images/5705.jpg
# /kaggle/input/classify-leaves/images/26623.jpg
# /kaggle/input/classify-leaves/images/19674.jpg
# /kaggle/input/classify-leaves/images/26142.jpg
# /kaggle/input/classify-leaves/images/8953.jpg
# /kaggle/input/classify-leaves/images/764.jpg
# /kaggle/input/classify-leaves/images/5307.jpg
# /kaggle/input/classify-leaves/images/7894.jpg
# /kaggle/input/classify-leaves/images/5039.jpg
# /kaggle/input/classify-leaves/images/10305.jpg
# /kaggle/input/classify-leaves/images/4407.jpg
# /kaggle/input/classify-leaves/images/1700.jpg
# /kaggle/input/classify-leaves/images/17257.jpg
# /kaggle/input/classify-leaves/images/1786.jpg
# /kaggle/input/classify-leaves/images/26946.jpg
# /kaggle/input/classify-leaves/images/17720.jpg
# /kaggle/input/classify-leaves/images/2907.jpg
# /kaggle/input/classify-leaves/images/8930.jpg
# /kaggle/input/classify-leaves/images/11138.jpg
# /kaggle/input/classify-leaves/images/16257.jpg
# /kaggle/input/classify-leaves/images/25501.jpg
# /kaggle/input/classify-leaves/images/6324.jpg
# /kaggle/input/classify-leaves/images/15979.jpg
# /kaggle/input/classify-leaves/images/1075.jpg
# /kaggle/input/classify-leaves/images/4969.jpg
# /kaggle/input/classify-leaves/images/18516.jpg
# /kaggle/input/classify-leaves/images/8983.jpg
# /kaggle/input/classify-leaves/images/5584.jpg
# /kaggle/input/classify-leaves/images/10627.jpg
# /kaggle/input/classify-leaves/images/23274.jpg
# /kaggle/input/classify-leaves/images/9697.jpg
# /kaggle/input/classify-leaves/images/3501.jpg
# /kaggle/input/classify-leaves/images/10037.jpg
# /kaggle/input/classify-leaves/images/2863.jpg
# /kaggle/input/classify-leaves/images/771.jpg
# /kaggle/input/classify-leaves/images/8352.jpg
# /kaggle/input/classify-leaves/images/208.jpg
# /kaggle/input/classify-leaves/images/23775.jpg
# /kaggle/input/classify-leaves/images/12167.jpg
# /kaggle/input/classify-leaves/images/17643.jpg
# /kaggle/input/classify-leaves/images/22046.jpg
# /kaggle/input/classify-leaves/images/11868.jpg
# /kaggle/input/classify-leaves/images/26853.jpg
# /kaggle/input/classify-leaves/images/14167.jpg
# /kaggle/input/classify-leaves/images/20938.jpg
# /kaggle/input/classify-leaves/images/4640.jpg
# /kaggle/input/classify-leaves/images/21590.jpg
# /kaggle/input/classify-leaves/images/7222.jpg
# /kaggle/input/classify-leaves/images/26538.jpg
# /kaggle/input/classify-leaves/images/17672.jpg
# /kaggle/input/classify-leaves/images/13839.jpg
# /kaggle/input/classify-leaves/images/26452.jpg
# /kaggle/input/classify-leaves/images/15082.jpg
# /kaggle/input/classify-leaves/images/5333.jpg
# /kaggle/input/classify-leaves/images/4125.jpg
# /kaggle/input/classify-leaves/images/14312.jpg
# /kaggle/input/classify-leaves/images/24667.jpg
# /kaggle/input/classify-leaves/images/6560.jpg
# /kaggle/input/classify-leaves/images/25858.jpg
# /kaggle/input/classify-leaves/images/23436.jpg
# /kaggle/input/classify-leaves/images/2628.jpg
# /kaggle/input/classify-leaves/images/26518.jpg
# /kaggle/input/classify-leaves/images/21575.jpg
# /kaggle/input/classify-leaves/images/23710.jpg
# /kaggle/input/classify-leaves/images/22604.jpg
# /kaggle/input/classify-leaves/images/16202.jpg
# /kaggle/input/classify-leaves/images/10162.jpg
# /kaggle/input/classify-leaves/images/15572.jpg
# /kaggle/input/classify-leaves/images/19901.jpg
# /kaggle/input/classify-leaves/images/8104.jpg
# /kaggle/input/classify-leaves/images/25261.jpg
# /kaggle/input/classify-leaves/images/3363.jpg
# /kaggle/input/classify-leaves/images/13333.jpg
# /kaggle/input/classify-leaves/images/4009.jpg
# /kaggle/input/classify-leaves/images/9645.jpg
# /kaggle/input/classify-leaves/images/15823.jpg
# /kaggle/input/classify-leaves/images/14395.jpg
# /kaggle/input/classify-leaves/images/25171.jpg
# /kaggle/input/classify-leaves/images/9579.jpg
# /kaggle/input/classify-leaves/images/20833.jpg
# /kaggle/input/classify-leaves/images/820.jpg
# /kaggle/input/classify-leaves/images/6943.jpg
# /kaggle/input/classify-leaves/images/3228.jpg
# /kaggle/input/classify-leaves/images/12132.jpg
# /kaggle/input/classify-leaves/images/20684.jpg
# /kaggle/input/classify-leaves/images/8075.jpg
# /kaggle/input/classify-leaves/images/18129.jpg
# /kaggle/input/classify-leaves/images/13899.jpg
# /kaggle/input/classify-leaves/images/26475.jpg
# /kaggle/input/classify-leaves/images/26107.jpg
# /kaggle/input/classify-leaves/images/6272.jpg
# /kaggle/input/classify-leaves/images/1789.jpg
# /kaggle/input/classify-leaves/images/6365.jpg
# /kaggle/input/classify-leaves/images/25869.jpg
# /kaggle/input/classify-leaves/images/20554.jpg
# /kaggle/input/classify-leaves/images/6459.jpg
# /kaggle/input/classify-leaves/images/5052.jpg
# /kaggle/input/classify-leaves/images/23753.jpg
# /kaggle/input/classify-leaves/images/7690.jpg
# /kaggle/input/classify-leaves/images/21966.jpg
# /kaggle/input/classify-leaves/images/15783.jpg
# /kaggle/input/classify-leaves/images/6653.jpg
# /kaggle/input/classify-leaves/images/23566.jpg
# /kaggle/input/classify-leaves/images/16385.jpg
# /kaggle/input/classify-leaves/images/473.jpg
# /kaggle/input/classify-leaves/images/8864.jpg
# /kaggle/input/classify-leaves/images/12768.jpg
# /kaggle/input/classify-leaves/images/23474.jpg
# /kaggle/input/classify-leaves/images/3446.jpg
# /kaggle/input/classify-leaves/images/13087.jpg
# /kaggle/input/classify-leaves/images/11034.jpg
# /kaggle/input/classify-leaves/images/1792.jpg
# /kaggle/input/classify-leaves/images/4772.jpg
# /kaggle/input/classify-leaves/images/16016.jpg
# /kaggle/input/classify-leaves/images/26591.jpg
# /kaggle/input/classify-leaves/images/21145.jpg
# /kaggle/input/classify-leaves/images/7427.jpg
# /kaggle/input/classify-leaves/images/24692.jpg
# /kaggle/input/classify-leaves/images/8623.jpg
# /kaggle/input/classify-leaves/images/7006.jpg
# /kaggle/input/classify-leaves/images/23273.jpg
# /kaggle/input/classify-leaves/images/12551.jpg
# /kaggle/input/classify-leaves/images/2936.jpg
# /kaggle/input/classify-leaves/images/2029.jpg
# /kaggle/input/classify-leaves/images/13118.jpg
# /kaggle/input/classify-leaves/images/6925.jpg
# /kaggle/input/classify-leaves/images/26803.jpg
# /kaggle/input/classify-leaves/images/4313.jpg
# /kaggle/input/classify-leaves/images/23031.jpg
# /kaggle/input/classify-leaves/images/6295.jpg
# /kaggle/input/classify-leaves/images/20010.jpg
# /kaggle/input/classify-leaves/images/5018.jpg
# /kaggle/input/classify-leaves/images/27092.jpg
# /kaggle/input/classify-leaves/images/24487.jpg
# /kaggle/input/classify-leaves/images/13205.jpg
# /kaggle/input/classify-leaves/images/10201.jpg
# /kaggle/input/classify-leaves/images/8914.jpg
# /kaggle/input/classify-leaves/images/15764.jpg
# /kaggle/input/classify-leaves/images/11251.jpg
# /kaggle/input/classify-leaves/images/1411.jpg
# /kaggle/input/classify-leaves/images/23098.jpg
# /kaggle/input/classify-leaves/images/7918.jpg
# /kaggle/input/classify-leaves/images/4275.jpg
# /kaggle/input/classify-leaves/images/7245.jpg
# /kaggle/input/classify-leaves/images/24392.jpg
# /kaggle/input/classify-leaves/images/24350.jpg
# /kaggle/input/classify-leaves/images/20100.jpg
# /kaggle/input/classify-leaves/images/22711.jpg
# /kaggle/input/classify-leaves/images/16401.jpg
# /kaggle/input/classify-leaves/images/3532.jpg
# /kaggle/input/classify-leaves/images/20789.jpg
# /kaggle/input/classify-leaves/images/7802.jpg
# /kaggle/input/classify-leaves/images/13911.jpg
# /kaggle/input/classify-leaves/images/1031.jpg
# /kaggle/input/classify-leaves/images/1833.jpg
# /kaggle/input/classify-leaves/images/11617.jpg
# /kaggle/input/classify-leaves/images/14397.jpg
# /kaggle/input/classify-leaves/images/20076.jpg
# /kaggle/input/classify-leaves/images/23258.jpg
# /kaggle/input/classify-leaves/images/14897.jpg
# /kaggle/input/classify-leaves/images/12389.jpg
# /kaggle/input/classify-leaves/images/23220.jpg
# /kaggle/input/classify-leaves/images/2675.jpg
# /kaggle/input/classify-leaves/images/5627.jpg
# /kaggle/input/classify-leaves/images/19651.jpg
# /kaggle/input/classify-leaves/images/6800.jpg
# /kaggle/input/classify-leaves/images/7962.jpg
# /kaggle/input/classify-leaves/images/11921.jpg
# /kaggle/input/classify-leaves/images/25779.jpg
# /kaggle/input/classify-leaves/images/23094.jpg
# /kaggle/input/classify-leaves/images/10255.jpg
# /kaggle/input/classify-leaves/images/10825.jpg
# /kaggle/input/classify-leaves/images/12414.jpg
# /kaggle/input/classify-leaves/images/18945.jpg
# /kaggle/input/classify-leaves/images/14376.jpg
# /kaggle/input/classify-leaves/images/25469.jpg
# /kaggle/input/classify-leaves/images/24969.jpg
# /kaggle/input/classify-leaves/images/21232.jpg
# /kaggle/input/classify-leaves/images/20321.jpg
# /kaggle/input/classify-leaves/images/13049.jpg
# /kaggle/input/classify-leaves/images/11236.jpg
# /kaggle/input/classify-leaves/images/12267.jpg
# /kaggle/input/classify-leaves/images/2172.jpg
# /kaggle/input/classify-leaves/images/18227.jpg
# /kaggle/input/classify-leaves/images/4765.jpg
# /kaggle/input/classify-leaves/images/22270.jpg
# /kaggle/input/classify-leaves/images/25990.jpg
# /kaggle/input/classify-leaves/images/21588.jpg
# /kaggle/input/classify-leaves/images/21947.jpg
# /kaggle/input/classify-leaves/images/6209.jpg
# /kaggle/input/classify-leaves/images/6899.jpg
# /kaggle/input/classify-leaves/images/18672.jpg
# /kaggle/input/classify-leaves/images/8442.jpg
# /kaggle/input/classify-leaves/images/11522.jpg
# /kaggle/input/classify-leaves/images/5068.jpg
# /kaggle/input/classify-leaves/images/11529.jpg
# /kaggle/input/classify-leaves/images/11956.jpg
# /kaggle/input/classify-leaves/images/6229.jpg
# /kaggle/input/classify-leaves/images/1749.jpg
# /kaggle/input/classify-leaves/images/1501.jpg
# /kaggle/input/classify-leaves/images/9606.jpg
# /kaggle/input/classify-leaves/images/14129.jpg
# /kaggle/input/classify-leaves/images/11684.jpg
# /kaggle/input/classify-leaves/images/8543.jpg
# /kaggle/input/classify-leaves/images/2021.jpg
# /kaggle/input/classify-leaves/images/15360.jpg
# /kaggle/input/classify-leaves/images/11855.jpg
# /kaggle/input/classify-leaves/images/14328.jpg
# /kaggle/input/classify-leaves/images/25310.jpg
# /kaggle/input/classify-leaves/images/17190.jpg
# /kaggle/input/classify-leaves/images/5886.jpg
# /kaggle/input/classify-leaves/images/18950.jpg
# /kaggle/input/classify-leaves/images/24778.jpg
# /kaggle/input/classify-leaves/images/21154.jpg
# /kaggle/input/classify-leaves/images/13314.jpg
# /kaggle/input/classify-leaves/images/7384.jpg
# /kaggle/input/classify-leaves/images/16652.jpg
# /kaggle/input/classify-leaves/images/3899.jpg
# /kaggle/input/classify-leaves/images/23596.jpg
# /kaggle/input/classify-leaves/images/24917.jpg
# /kaggle/input/classify-leaves/images/1995.jpg
# /kaggle/input/classify-leaves/images/5477.jpg
# /kaggle/input/classify-leaves/images/20978.jpg
# /kaggle/input/classify-leaves/images/24068.jpg
# /kaggle/input/classify-leaves/images/1385.jpg
# /kaggle/input/classify-leaves/images/3651.jpg
# /kaggle/input/classify-leaves/images/8342.jpg
# /kaggle/input/classify-leaves/images/13200.jpg
# /kaggle/input/classify-leaves/images/18048.jpg
# /kaggle/input/classify-leaves/images/15103.jpg
# /kaggle/input/classify-leaves/images/7544.jpg
# /kaggle/input/classify-leaves/images/4398.jpg
# /kaggle/input/classify-leaves/images/19407.jpg
# /kaggle/input/classify-leaves/images/4581.jpg
# /kaggle/input/classify-leaves/images/16504.jpg
# /kaggle/input/classify-leaves/images/12334.jpg
# /kaggle/input/classify-leaves/images/20429.jpg
# /kaggle/input/classify-leaves/images/3537.jpg
# /kaggle/input/classify-leaves/images/21946.jpg
# /kaggle/input/classify-leaves/images/16638.jpg
# /kaggle/input/classify-leaves/images/5575.jpg
# /kaggle/input/classify-leaves/images/20825.jpg
# /kaggle/input/classify-leaves/images/2278.jpg
# /kaggle/input/classify-leaves/images/21701.jpg
# /kaggle/input/classify-leaves/images/11901.jpg
# /kaggle/input/classify-leaves/images/26474.jpg
# /kaggle/input/classify-leaves/images/25558.jpg
# /kaggle/input/classify-leaves/images/12675.jpg
# /kaggle/input/classify-leaves/images/24267.jpg
# /kaggle/input/classify-leaves/images/17474.jpg
# /kaggle/input/classify-leaves/images/20906.jpg
# /kaggle/input/classify-leaves/images/15785.jpg
# /kaggle/input/classify-leaves/images/24785.jpg
# /kaggle/input/classify-leaves/images/14619.jpg
# /kaggle/input/classify-leaves/images/6831.jpg
# /kaggle/input/classify-leaves/images/20308.jpg
# /kaggle/input/classify-leaves/images/18399.jpg
# /kaggle/input/classify-leaves/images/18700.jpg
# /kaggle/input/classify-leaves/images/8929.jpg
# /kaggle/input/classify-leaves/images/1971.jpg
# /kaggle/input/classify-leaves/images/13594.jpg
# /kaggle/input/classify-leaves/images/12882.jpg
# /kaggle/input/classify-leaves/images/6248.jpg
# /kaggle/input/classify-leaves/images/18335.jpg
# /kaggle/input/classify-leaves/images/7061.jpg
# /kaggle/input/classify-leaves/images/26320.jpg
# /kaggle/input/classify-leaves/images/26291.jpg
# /kaggle/input/classify-leaves/images/16993.jpg
# /kaggle/input/classify-leaves/images/21093.jpg
# /kaggle/input/classify-leaves/images/12303.jpg
# /kaggle/input/classify-leaves/images/3807.jpg
# /kaggle/input/classify-leaves/images/1383.jpg
# /kaggle/input/classify-leaves/images/15463.jpg
# /kaggle/input/classify-leaves/images/23053.jpg
# /kaggle/input/classify-leaves/images/12532.jpg
# /kaggle/input/classify-leaves/images/9887.jpg
# /kaggle/input/classify-leaves/images/15030.jpg
# /kaggle/input/classify-leaves/images/6337.jpg
# /kaggle/input/classify-leaves/images/8612.jpg
# /kaggle/input/classify-leaves/images/20381.jpg
# /kaggle/input/classify-leaves/images/20760.jpg
# /kaggle/input/classify-leaves/images/12588.jpg
# /kaggle/input/classify-leaves/images/11382.jpg
# /kaggle/input/classify-leaves/images/13422.jpg
# /kaggle/input/classify-leaves/images/8218.jpg
# /kaggle/input/classify-leaves/images/16654.jpg
# /kaggle/input/classify-leaves/images/333.jpg
# /kaggle/input/classify-leaves/images/8379.jpg
# /kaggle/input/classify-leaves/images/1354.jpg
# /kaggle/input/classify-leaves/images/11087.jpg
# /kaggle/input/classify-leaves/images/25902.jpg
# /kaggle/input/classify-leaves/images/5976.jpg
# /kaggle/input/classify-leaves/images/1024.jpg
# /kaggle/input/classify-leaves/images/537.jpg
# /kaggle/input/classify-leaves/images/6513.jpg
# /kaggle/input/classify-leaves/images/7706.jpg
# /kaggle/input/classify-leaves/images/18013.jpg
# /kaggle/input/classify-leaves/images/10039.jpg
# /kaggle/input/classify-leaves/images/25142.jpg
# /kaggle/input/classify-leaves/images/3014.jpg
# /kaggle/input/classify-leaves/images/13377.jpg
# /kaggle/input/classify-leaves/images/22118.jpg
# /kaggle/input/classify-leaves/images/20874.jpg
# /kaggle/input/classify-leaves/images/19382.jpg
# /kaggle/input/classify-leaves/images/8120.jpg
# /kaggle/input/classify-leaves/images/17587.jpg
# /kaggle/input/classify-leaves/images/25178.jpg
# /kaggle/input/classify-leaves/images/16481.jpg
# /kaggle/input/classify-leaves/images/5147.jpg
# /kaggle/input/classify-leaves/images/21787.jpg
# /kaggle/input/classify-leaves/images/26534.jpg
# /kaggle/input/classify-leaves/images/45.jpg
# /kaggle/input/classify-leaves/images/2375.jpg
# /kaggle/input/classify-leaves/images/25677.jpg
# /kaggle/input/classify-leaves/images/19857.jpg
# /kaggle/input/classify-leaves/images/7941.jpg
# /kaggle/input/classify-leaves/images/23625.jpg
# /kaggle/input/classify-leaves/images/11848.jpg
# /kaggle/input/classify-leaves/images/10550.jpg
# /kaggle/input/classify-leaves/images/9486.jpg
# /kaggle/input/classify-leaves/images/25532.jpg
# /kaggle/input/classify-leaves/images/369.jpg
# /kaggle/input/classify-leaves/images/22666.jpg
# /kaggle/input/classify-leaves/images/1626.jpg
# /kaggle/input/classify-leaves/images/18980.jpg
# /kaggle/input/classify-leaves/images/6493.jpg
# /kaggle/input/classify-leaves/images/18311.jpg
# /kaggle/input/classify-leaves/images/5734.jpg
# /kaggle/input/classify-leaves/images/22459.jpg
# /kaggle/input/classify-leaves/images/13673.jpg
# /kaggle/input/classify-leaves/images/56.jpg
# /kaggle/input/classify-leaves/images/16943.jpg
# /kaggle/input/classify-leaves/images/14159.jpg
# /kaggle/input/classify-leaves/images/23082.jpg
# /kaggle/input/classify-leaves/images/6797.jpg
# /kaggle/input/classify-leaves/images/20987.jpg
# /kaggle/input/classify-leaves/images/8444.jpg
# /kaggle/input/classify-leaves/images/20937.jpg
# /kaggle/input/classify-leaves/images/654.jpg
# /kaggle/input/classify-leaves/images/10598.jpg
# /kaggle/input/classify-leaves/images/26688.jpg
# /kaggle/input/classify-leaves/images/4437.jpg
# /kaggle/input/classify-leaves/images/18935.jpg
# /kaggle/input/classify-leaves/images/25943.jpg
# /kaggle/input/classify-leaves/images/14597.jpg
# /kaggle/input/classify-leaves/images/6794.jpg
# /kaggle/input/classify-leaves/images/13614.jpg
# /kaggle/input/classify-leaves/images/24439.jpg
# /kaggle/input/classify-leaves/images/25946.jpg
# /kaggle/input/classify-leaves/images/20267.jpg
# /kaggle/input/classify-leaves/images/9462.jpg
# /kaggle/input/classify-leaves/images/16723.jpg
# /kaggle/input/classify-leaves/images/17973.jpg
# /kaggle/input/classify-leaves/images/11682.jpg
# /kaggle/input/classify-leaves/images/19792.jpg
# /kaggle/input/classify-leaves/images/22945.jpg
# /kaggle/input/classify-leaves/images/26297.jpg
# /kaggle/input/classify-leaves/images/8643.jpg
# /kaggle/input/classify-leaves/images/9493.jpg
# /kaggle/input/classify-leaves/images/13400.jpg
# /kaggle/input/classify-leaves/images/21493.jpg
# /kaggle/input/classify-leaves/images/89.jpg
# /kaggle/input/classify-leaves/images/1711.jpg
# /kaggle/input/classify-leaves/images/11428.jpg
# /kaggle/input/classify-leaves/images/19888.jpg
# /kaggle/input/classify-leaves/images/6367.jpg
# /kaggle/input/classify-leaves/images/19224.jpg
# /kaggle/input/classify-leaves/images/18854.jpg
# /kaggle/input/classify-leaves/images/12328.jpg
# /kaggle/input/classify-leaves/images/18638.jpg
# /kaggle/input/classify-leaves/images/5853.jpg
# /kaggle/input/classify-leaves/images/12068.jpg
# /kaggle/input/classify-leaves/images/15578.jpg
# /kaggle/input/classify-leaves/images/20475.jpg
# /kaggle/input/classify-leaves/images/26201.jpg
# /kaggle/input/classify-leaves/images/16575.jpg
# /kaggle/input/classify-leaves/images/5534.jpg
# /kaggle/input/classify-leaves/images/20.jpg
# /kaggle/input/classify-leaves/images/25241.jpg
# /kaggle/input/classify-leaves/images/24554.jpg
# /kaggle/input/classify-leaves/images/7516.jpg
# /kaggle/input/classify-leaves/images/9083.jpg
# /kaggle/input/classify-leaves/images/21612.jpg
# /kaggle/input/classify-leaves/images/1339.jpg
# /kaggle/input/classify-leaves/images/14510.jpg
# /kaggle/input/classify-leaves/images/6894.jpg
# /kaggle/input/classify-leaves/images/26917.jpg
# /kaggle/input/classify-leaves/images/4979.jpg
# /kaggle/input/classify-leaves/images/12770.jpg
# /kaggle/input/classify-leaves/images/22742.jpg
# /kaggle/input/classify-leaves/images/12101.jpg
# /kaggle/input/classify-leaves/images/15911.jpg
# /kaggle/input/classify-leaves/images/12205.jpg
# /kaggle/input/classify-leaves/images/14059.jpg
# /kaggle/input/classify-leaves/images/9251.jpg
# /kaggle/input/classify-leaves/images/21126.jpg
# /kaggle/input/classify-leaves/images/8003.jpg
# /kaggle/input/classify-leaves/images/5392.jpg
# /kaggle/input/classify-leaves/images/18702.jpg
# /kaggle/input/classify-leaves/images/6952.jpg
# /kaggle/input/classify-leaves/images/4351.jpg
# /kaggle/input/classify-leaves/images/14141.jpg
# /kaggle/input/classify-leaves/images/10062.jpg
# /kaggle/input/classify-leaves/images/24287.jpg
# /kaggle/input/classify-leaves/images/20079.jpg
# /kaggle/input/classify-leaves/images/9589.jpg
# /kaggle/input/classify-leaves/images/20762.jpg
# /kaggle/input/classify-leaves/images/12941.jpg
# /kaggle/input/classify-leaves/images/6059.jpg
# /kaggle/input/classify-leaves/images/275.jpg
# /kaggle/input/classify-leaves/images/15794.jpg
# /kaggle/input/classify-leaves/images/16895.jpg
# /kaggle/input/classify-leaves/images/24065.jpg
# /kaggle/input/classify-leaves/images/12999.jpg
# /kaggle/input/classify-leaves/images/23412.jpg
# /kaggle/input/classify-leaves/images/22798.jpg
# /kaggle/input/classify-leaves/images/19251.jpg
# /kaggle/input/classify-leaves/images/10075.jpg
# /kaggle/input/classify-leaves/images/6458.jpg
# /kaggle/input/classify-leaves/images/3670.jpg
# /kaggle/input/classify-leaves/images/13598.jpg
# /kaggle/input/classify-leaves/images/19727.jpg
# /kaggle/input/classify-leaves/images/5882.jpg
# /kaggle/input/classify-leaves/images/20042.jpg
# /kaggle/input/classify-leaves/images/2532.jpg
# /kaggle/input/classify-leaves/images/11058.jpg
# /kaggle/input/classify-leaves/images/17091.jpg
# /kaggle/input/classify-leaves/images/1161.jpg
# /kaggle/input/classify-leaves/images/11849.jpg
# /kaggle/input/classify-leaves/images/15872.jpg
# /kaggle/input/classify-leaves/images/15194.jpg
# /kaggle/input/classify-leaves/images/9868.jpg
# /kaggle/input/classify-leaves/images/14911.jpg
# /kaggle/input/classify-leaves/images/22108.jpg
# /kaggle/input/classify-leaves/images/14103.jpg
# /kaggle/input/classify-leaves/images/13624.jpg
# /kaggle/input/classify-leaves/images/26541.jpg
# /kaggle/input/classify-leaves/images/785.jpg
# /kaggle/input/classify-leaves/images/19947.jpg
# /kaggle/input/classify-leaves/images/2262.jpg
# /kaggle/input/classify-leaves/images/10611.jpg
# /kaggle/input/classify-leaves/images/2213.jpg
# /kaggle/input/classify-leaves/images/18482.jpg
# /kaggle/input/classify-leaves/images/18708.jpg
# /kaggle/input/classify-leaves/images/23819.jpg
# /kaggle/input/classify-leaves/images/9336.jpg
# /kaggle/input/classify-leaves/images/19776.jpg
# /kaggle/input/classify-leaves/images/25195.jpg
# /kaggle/input/classify-leaves/images/3645.jpg
# /kaggle/input/classify-leaves/images/1940.jpg
# /kaggle/input/classify-leaves/images/1777.jpg
# /kaggle/input/classify-leaves/images/22368.jpg
# /kaggle/input/classify-leaves/images/8328.jpg
# /kaggle/input/classify-leaves/images/1380.jpg
# /kaggle/input/classify-leaves/images/16360.jpg
# /kaggle/input/classify-leaves/images/9999.jpg
# /kaggle/input/classify-leaves/images/19833.jpg
# /kaggle/input/classify-leaves/images/23272.jpg
# /kaggle/input/classify-leaves/images/15953.jpg
# /kaggle/input/classify-leaves/images/11690.jpg
# /kaggle/input/classify-leaves/images/4899.jpg
# /kaggle/input/classify-leaves/images/11524.jpg
# /kaggle/input/classify-leaves/images/11895.jpg
# /kaggle/input/classify-leaves/images/6924.jpg
# /kaggle/input/classify-leaves/images/26053.jpg
# /kaggle/input/classify-leaves/images/24355.jpg
# /kaggle/input/classify-leaves/images/16679.jpg
# /kaggle/input/classify-leaves/images/26582.jpg
# /kaggle/input/classify-leaves/images/212.jpg
# /kaggle/input/classify-leaves/images/7440.jpg
# /kaggle/input/classify-leaves/images/19998.jpg
# /kaggle/input/classify-leaves/images/24482.jpg
# /kaggle/input/classify-leaves/images/22445.jpg
# /kaggle/input/classify-leaves/images/24437.jpg
# /kaggle/input/classify-leaves/images/5482.jpg
# /kaggle/input/classify-leaves/images/19165.jpg
# /kaggle/input/classify-leaves/images/12838.jpg
# /kaggle/input/classify-leaves/images/6867.jpg
# /kaggle/input/classify-leaves/images/5852.jpg
# /kaggle/input/classify-leaves/images/239.jpg
# /kaggle/input/classify-leaves/images/4081.jpg
# /kaggle/input/classify-leaves/images/792.jpg
# /kaggle/input/classify-leaves/images/24083.jpg
# /kaggle/input/classify-leaves/images/2057.jpg
# /kaggle/input/classify-leaves/images/25153.jpg
# /kaggle/input/classify-leaves/images/1009.jpg
# /kaggle/input/classify-leaves/images/21278.jpg
# /kaggle/input/classify-leaves/images/12540.jpg
# /kaggle/input/classify-leaves/images/17983.jpg
# /kaggle/input/classify-leaves/images/21582.jpg
# /kaggle/input/classify-leaves/images/6196.jpg
# /kaggle/input/classify-leaves/images/19747.jpg
# /kaggle/input/classify-leaves/images/3295.jpg
# /kaggle/input/classify-leaves/images/17763.jpg
# /kaggle/input/classify-leaves/images/25069.jpg
# /kaggle/input/classify-leaves/images/25006.jpg
# /kaggle/input/classify-leaves/images/16406.jpg
# /kaggle/input/classify-leaves/images/25997.jpg
# /kaggle/input/classify-leaves/images/26855.jpg
# /kaggle/input/classify-leaves/images/15317.jpg
# /kaggle/input/classify-leaves/images/23351.jpg
# /kaggle/input/classify-leaves/images/14737.jpg
# /kaggle/input/classify-leaves/images/13737.jpg
# /kaggle/input/classify-leaves/images/5371.jpg
# /kaggle/input/classify-leaves/images/8592.jpg
# /kaggle/input/classify-leaves/images/5941.jpg
# /kaggle/input/classify-leaves/images/21144.jpg
# /kaggle/input/classify-leaves/images/24036.jpg
# /kaggle/input/classify-leaves/images/5158.jpg
# /kaggle/input/classify-leaves/images/23924.jpg
# /kaggle/input/classify-leaves/images/21207.jpg
# /kaggle/input/classify-leaves/images/23906.jpg
# /kaggle/input/classify-leaves/images/14843.jpg
# /kaggle/input/classify-leaves/images/23008.jpg
# /kaggle/input/classify-leaves/images/14122.jpg
# /kaggle/input/classify-leaves/images/25547.jpg
# /kaggle/input/classify-leaves/images/19596.jpg
# /kaggle/input/classify-leaves/images/3937.jpg
# /kaggle/input/classify-leaves/images/21808.jpg
# /kaggle/input/classify-leaves/images/19079.jpg
# /kaggle/input/classify-leaves/images/17796.jpg
# /kaggle/input/classify-leaves/images/6917.jpg
# /kaggle/input/classify-leaves/images/24343.jpg
# /kaggle/input/classify-leaves/images/10651.jpg
# /kaggle/input/classify-leaves/images/9388.jpg
# /kaggle/input/classify-leaves/images/10880.jpg
# /kaggle/input/classify-leaves/images/17832.jpg
# /kaggle/input/classify-leaves/images/18451.jpg
# /kaggle/input/classify-leaves/images/2094.jpg
# /kaggle/input/classify-leaves/images/1157.jpg
# /kaggle/input/classify-leaves/images/18426.jpg
# /kaggle/input/classify-leaves/images/12493.jpg
# /kaggle/input/classify-leaves/images/58.jpg
# /kaggle/input/classify-leaves/images/16519.jpg
# /kaggle/input/classify-leaves/images/2302.jpg
# /kaggle/input/classify-leaves/images/13928.jpg
# /kaggle/input/classify-leaves/images/21495.jpg
# /kaggle/input/classify-leaves/images/12421.jpg
# /kaggle/input/classify-leaves/images/26922.jpg
# /kaggle/input/classify-leaves/images/6190.jpg
# /kaggle/input/classify-leaves/images/24943.jpg
# /kaggle/input/classify-leaves/images/17959.jpg
# /kaggle/input/classify-leaves/images/17291.jpg
# /kaggle/input/classify-leaves/images/8340.jpg
# /kaggle/input/classify-leaves/images/13217.jpg
# /kaggle/input/classify-leaves/images/3816.jpg
# /kaggle/input/classify-leaves/images/2695.jpg
# /kaggle/input/classify-leaves/images/10849.jpg
# /kaggle/input/classify-leaves/images/13420.jpg
# /kaggle/input/classify-leaves/images/22356.jpg
# /kaggle/input/classify-leaves/images/24731.jpg
# /kaggle/input/classify-leaves/images/22433.jpg
# /kaggle/input/classify-leaves/images/19465.jpg
# /kaggle/input/classify-leaves/images/20578.jpg
# /kaggle/input/classify-leaves/images/1304.jpg
# /kaggle/input/classify-leaves/images/21392.jpg
# /kaggle/input/classify-leaves/images/7512.jpg
# /kaggle/input/classify-leaves/images/6796.jpg
# /kaggle/input/classify-leaves/images/23111.jpg
# /kaggle/input/classify-leaves/images/14919.jpg
# /kaggle/input/classify-leaves/images/11024.jpg
# /kaggle/input/classify-leaves/images/14105.jpg
# /kaggle/input/classify-leaves/images/25145.jpg
# /kaggle/input/classify-leaves/images/25052.jpg
# /kaggle/input/classify-leaves/images/25005.jpg
# /kaggle/input/classify-leaves/images/14476.jpg
# /kaggle/input/classify-leaves/images/23881.jpg
# /kaggle/input/classify-leaves/images/1340.jpg
# /kaggle/input/classify-leaves/images/15326.jpg
# /kaggle/input/classify-leaves/images/24944.jpg
# /kaggle/input/classify-leaves/images/21809.jpg
# /kaggle/input/classify-leaves/images/1760.jpg
# /kaggle/input/classify-leaves/images/5458.jpg
# /kaggle/input/classify-leaves/images/2028.jpg
# /kaggle/input/classify-leaves/images/19063.jpg
# /kaggle/input/classify-leaves/images/24911.jpg
# /kaggle/input/classify-leaves/images/14539.jpg
# /kaggle/input/classify-leaves/images/4166.jpg
# /kaggle/input/classify-leaves/images/11641.jpg
# /kaggle/input/classify-leaves/images/1173.jpg
# /kaggle/input/classify-leaves/images/6237.jpg
# /kaggle/input/classify-leaves/images/1790.jpg
# /kaggle/input/classify-leaves/images/26295.jpg
# /kaggle/input/classify-leaves/images/6000.jpg
# /kaggle/input/classify-leaves/images/6709.jpg
# /kaggle/input/classify-leaves/images/22439.jpg
# /kaggle/input/classify-leaves/images/15261.jpg
# /kaggle/input/classify-leaves/images/6605.jpg
# /kaggle/input/classify-leaves/images/19273.jpg
# /kaggle/input/classify-leaves/images/150.jpg
# /kaggle/input/classify-leaves/images/6719.jpg
# /kaggle/input/classify-leaves/images/25267.jpg
# /kaggle/input/classify-leaves/images/21118.jpg
# /kaggle/input/classify-leaves/images/2137.jpg
# /kaggle/input/classify-leaves/images/3729.jpg
# /kaggle/input/classify-leaves/images/13952.jpg
# /kaggle/input/classify-leaves/images/8445.jpg
# /kaggle/input/classify-leaves/images/26899.jpg
# /kaggle/input/classify-leaves/images/6.jpg
# /kaggle/input/classify-leaves/images/3364.jpg
# /kaggle/input/classify-leaves/images/109.jpg
# /kaggle/input/classify-leaves/images/6941.jpg
# /kaggle/input/classify-leaves/images/5998.jpg
# /kaggle/input/classify-leaves/images/26023.jpg
# /kaggle/input/classify-leaves/images/15689.jpg
# /kaggle/input/classify-leaves/images/8369.jpg
# /kaggle/input/classify-leaves/images/13476.jpg
# /kaggle/input/classify-leaves/images/2654.jpg
# /kaggle/input/classify-leaves/images/1650.jpg
# /kaggle/input/classify-leaves/images/11265.jpg
# /kaggle/input/classify-leaves/images/7986.jpg
# /kaggle/input/classify-leaves/images/19699.jpg
# /kaggle/input/classify-leaves/images/20990.jpg
# /kaggle/input/classify-leaves/images/15404.jpg
# /kaggle/input/classify-leaves/images/22606.jpg
# /kaggle/input/classify-leaves/images/15757.jpg
# /kaggle/input/classify-leaves/images/19585.jpg
# /kaggle/input/classify-leaves/images/1211.jpg
# /kaggle/input/classify-leaves/images/12483.jpg
# /kaggle/input/classify-leaves/images/15255.jpg
# /kaggle/input/classify-leaves/images/12679.jpg
# /kaggle/input/classify-leaves/images/3310.jpg
# /kaggle/input/classify-leaves/images/11751.jpg
# /kaggle/input/classify-leaves/images/24883.jpg
# /kaggle/input/classify-leaves/images/23776.jpg
# /kaggle/input/classify-leaves/images/8979.jpg
# /kaggle/input/classify-leaves/images/13287.jpg
# /kaggle/input/classify-leaves/images/15724.jpg
# /kaggle/input/classify-leaves/images/3209.jpg
# /kaggle/input/classify-leaves/images/24471.jpg
# /kaggle/input/classify-leaves/images/19715.jpg
# /kaggle/input/classify-leaves/images/8367.jpg
# /kaggle/input/classify-leaves/images/24525.jpg
# /kaggle/input/classify-leaves/images/4812.jpg
# /kaggle/input/classify-leaves/images/23915.jpg
# /kaggle/input/classify-leaves/images/17232.jpg
# /kaggle/input/classify-leaves/images/9037.jpg
# /kaggle/input/classify-leaves/images/23713.jpg
# /kaggle/input/classify-leaves/images/22860.jpg
# /kaggle/input/classify-leaves/images/8852.jpg
# /kaggle/input/classify-leaves/images/5330.jpg
# /kaggle/input/classify-leaves/images/12464.jpg
# /kaggle/input/classify-leaves/images/13374.jpg
# /kaggle/input/classify-leaves/images/17836.jpg
# /kaggle/input/classify-leaves/images/22366.jpg
# /kaggle/input/classify-leaves/images/2319.jpg
# /kaggle/input/classify-leaves/images/18626.jpg
# /kaggle/input/classify-leaves/images/20061.jpg
# /kaggle/input/classify-leaves/images/6715.jpg
# /kaggle/input/classify-leaves/images/149.jpg
# /kaggle/input/classify-leaves/images/1488.jpg
# /kaggle/input/classify-leaves/images/16675.jpg
# /kaggle/input/classify-leaves/images/22422.jpg
# /kaggle/input/classify-leaves/images/20572.jpg
# /kaggle/input/classify-leaves/images/8026.jpg
# /kaggle/input/classify-leaves/images/11452.jpg
# /kaggle/input/classify-leaves/images/23415.jpg
# /kaggle/input/classify-leaves/images/11422.jpg
# /kaggle/input/classify-leaves/images/26432.jpg
# /kaggle/input/classify-leaves/images/5056.jpg
# /kaggle/input/classify-leaves/images/24984.jpg
# /kaggle/input/classify-leaves/images/15949.jpg
# /kaggle/input/classify-leaves/images/13880.jpg
# /kaggle/input/classify-leaves/images/24865.jpg
# /kaggle/input/classify-leaves/images/17244.jpg
# /kaggle/input/classify-leaves/images/14523.jpg
# /kaggle/input/classify-leaves/images/9135.jpg
# /kaggle/input/classify-leaves/images/26261.jpg
# /kaggle/input/classify-leaves/images/1862.jpg
# /kaggle/input/classify-leaves/images/1167.jpg
# /kaggle/input/classify-leaves/images/11678.jpg
# /kaggle/input/classify-leaves/images/1644.jpg
# /kaggle/input/classify-leaves/images/1539.jpg
# /kaggle/input/classify-leaves/images/10643.jpg
# /kaggle/input/classify-leaves/images/26393.jpg
# /kaggle/input/classify-leaves/images/4494.jpg
# /kaggle/input/classify-leaves/images/14730.jpg
# /kaggle/input/classify-leaves/images/17965.jpg
# /kaggle/input/classify-leaves/images/12424.jpg
# /kaggle/input/classify-leaves/images/20839.jpg
# /kaggle/input/classify-leaves/images/2640.jpg
# /kaggle/input/classify-leaves/images/6856.jpg
# /kaggle/input/classify-leaves/images/20687.jpg
# /kaggle/input/classify-leaves/images/4373.jpg
# /kaggle/input/classify-leaves/images/21375.jpg
# /kaggle/input/classify-leaves/images/187.jpg
# /kaggle/input/classify-leaves/images/17490.jpg
# /kaggle/input/classify-leaves/images/521.jpg
# /kaggle/input/classify-leaves/images/16528.jpg
# /kaggle/input/classify-leaves/images/17840.jpg
# /kaggle/input/classify-leaves/images/12739.jpg
# /kaggle/input/classify-leaves/images/436.jpg
# /kaggle/input/classify-leaves/images/10500.jpg
# /kaggle/input/classify-leaves/images/17103.jpg
# /kaggle/input/classify-leaves/images/12141.jpg
# /kaggle/input/classify-leaves/images/14259.jpg
# /kaggle/input/classify-leaves/images/19654.jpg
# /kaggle/input/classify-leaves/images/6203.jpg
# /kaggle/input/classify-leaves/images/25864.jpg
# /kaggle/input/classify-leaves/images/8950.jpg
# /kaggle/input/classify-leaves/images/8112.jpg
# /kaggle/input/classify-leaves/images/4439.jpg
# /kaggle/input/classify-leaves/images/12165.jpg
# /kaggle/input/classify-leaves/images/18163.jpg
# /kaggle/input/classify-leaves/images/12272.jpg
# /kaggle/input/classify-leaves/images/20222.jpg
# /kaggle/input/classify-leaves/images/76.jpg
# /kaggle/input/classify-leaves/images/21585.jpg
# /kaggle/input/classify-leaves/images/15036.jpg
# /kaggle/input/classify-leaves/images/21706.jpg
# /kaggle/input/classify-leaves/images/539.jpg
# /kaggle/input/classify-leaves/images/12759.jpg
# /kaggle/input/classify-leaves/images/3330.jpg
# /kaggle/input/classify-leaves/images/2844.jpg
# /kaggle/input/classify-leaves/images/5817.jpg
# /kaggle/input/classify-leaves/images/11321.jpg
# /kaggle/input/classify-leaves/images/24653.jpg
# /kaggle/input/classify-leaves/images/5132.jpg
# /kaggle/input/classify-leaves/images/17916.jpg
# /kaggle/input/classify-leaves/images/15027.jpg
# /kaggle/input/classify-leaves/images/5943.jpg
# /kaggle/input/classify-leaves/images/3732.jpg
# /kaggle/input/classify-leaves/images/9257.jpg
# /kaggle/input/classify-leaves/images/6213.jpg
# /kaggle/input/classify-leaves/images/24829.jpg
# /kaggle/input/classify-leaves/images/23424.jpg
# /kaggle/input/classify-leaves/images/1355.jpg
# /kaggle/input/classify-leaves/images/355.jpg
# /kaggle/input/classify-leaves/images/26125.jpg
# /kaggle/input/classify-leaves/images/11153.jpg
# /kaggle/input/classify-leaves/images/21180.jpg
# /kaggle/input/classify-leaves/images/11774.jpg
# /kaggle/input/classify-leaves/images/24630.jpg
# /kaggle/input/classify-leaves/images/9859.jpg
# /kaggle/input/classify-leaves/images/17799.jpg
# /kaggle/input/classify-leaves/images/20854.jpg
# /kaggle/input/classify-leaves/images/11763.jpg
# /kaggle/input/classify-leaves/images/2899.jpg
# /kaggle/input/classify-leaves/images/18763.jpg
# /kaggle/input/classify-leaves/images/17211.jpg
# /kaggle/input/classify-leaves/images/16013.jpg
# /kaggle/input/classify-leaves/images/10538.jpg
# /kaggle/input/classify-leaves/images/22039.jpg
# /kaggle/input/classify-leaves/images/5117.jpg
# /kaggle/input/classify-leaves/images/22254.jpg
# /kaggle/input/classify-leaves/images/25952.jpg
# /kaggle/input/classify-leaves/images/12374.jpg
# /kaggle/input/classify-leaves/images/22932.jpg
# /kaggle/input/classify-leaves/images/20302.jpg
# /kaggle/input/classify-leaves/images/15247.jpg
# /kaggle/input/classify-leaves/images/18226.jpg
# /kaggle/input/classify-leaves/images/16733.jpg
# /kaggle/input/classify-leaves/images/12959.jpg
# /kaggle/input/classify-leaves/images/2041.jpg
# /kaggle/input/classify-leaves/images/9222.jpg
# /kaggle/input/classify-leaves/images/15621.jpg
# /kaggle/input/classify-leaves/images/22019.jpg
# /kaggle/input/classify-leaves/images/15370.jpg
# /kaggle/input/classify-leaves/images/16375.jpg
# /kaggle/input/classify-leaves/images/8555.jpg
# /kaggle/input/classify-leaves/images/7468.jpg
# /kaggle/input/classify-leaves/images/8380.jpg
# /kaggle/input/classify-leaves/images/3546.jpg
# /kaggle/input/classify-leaves/images/9364.jpg
# /kaggle/input/classify-leaves/images/14104.jpg
# /kaggle/input/classify-leaves/images/10383.jpg
# /kaggle/input/classify-leaves/images/1565.jpg
# /kaggle/input/classify-leaves/images/14021.jpg
# /kaggle/input/classify-leaves/images/4815.jpg
# /kaggle/input/classify-leaves/images/17839.jpg
# /kaggle/input/classify-leaves/images/19847.jpg
# /kaggle/input/classify-leaves/images/516.jpg
# /kaggle/input/classify-leaves/images/8128.jpg
# /kaggle/input/classify-leaves/images/1409.jpg
# /kaggle/input/classify-leaves/images/4039.jpg
# /kaggle/input/classify-leaves/images/71.jpg
# /kaggle/input/classify-leaves/images/24336.jpg
# /kaggle/input/classify-leaves/images/21034.jpg
# /kaggle/input/classify-leaves/images/7292.jpg
# /kaggle/input/classify-leaves/images/7296.jpg
# /kaggle/input/classify-leaves/images/22682.jpg
# /kaggle/input/classify-leaves/images/22176.jpg
# /kaggle/input/classify-leaves/images/708.jpg
# /kaggle/input/classify-leaves/images/15608.jpg
# /kaggle/input/classify-leaves/images/21236.jpg
# /kaggle/input/classify-leaves/images/19254.jpg
# /kaggle/input/classify-leaves/images/3539.jpg
# /kaggle/input/classify-leaves/images/1222.jpg
# /kaggle/input/classify-leaves/images/4986.jpg
# /kaggle/input/classify-leaves/images/1154.jpg
# /kaggle/input/classify-leaves/images/11882.jpg
# /kaggle/input/classify-leaves/images/3743.jpg
# /kaggle/input/classify-leaves/images/11619.jpg
# /kaggle/input/classify-leaves/images/6957.jpg
# /kaggle/input/classify-leaves/images/16087.jpg
# /kaggle/input/classify-leaves/images/13030.jpg
# /kaggle/input/classify-leaves/images/4188.jpg
# /kaggle/input/classify-leaves/images/5091.jpg
# /kaggle/input/classify-leaves/images/17550.jpg
# /kaggle/input/classify-leaves/images/19252.jpg
# /kaggle/input/classify-leaves/images/25290.jpg
# /kaggle/input/classify-leaves/images/11106.jpg
# /kaggle/input/classify-leaves/images/13723.jpg
# /kaggle/input/classify-leaves/images/18612.jpg
# /kaggle/input/classify-leaves/images/9331.jpg
# /kaggle/input/classify-leaves/images/7338.jpg
# /kaggle/input/classify-leaves/images/18545.jpg
# /kaggle/input/classify-leaves/images/19791.jpg
# /kaggle/input/classify-leaves/images/474.jpg
# /kaggle/input/classify-leaves/images/21022.jpg
# /kaggle/input/classify-leaves/images/15374.jpg
# /kaggle/input/classify-leaves/images/17622.jpg
# /kaggle/input/classify-leaves/images/14719.jpg
# /kaggle/input/classify-leaves/images/26880.jpg
# /kaggle/input/classify-leaves/images/16006.jpg
# /kaggle/input/classify-leaves/images/18771.jpg
# /kaggle/input/classify-leaves/images/20917.jpg
# /kaggle/input/classify-leaves/images/5789.jpg
# /kaggle/input/classify-leaves/images/19526.jpg
# /kaggle/input/classify-leaves/images/10405.jpg
# /kaggle/input/classify-leaves/images/21668.jpg
# /kaggle/input/classify-leaves/images/5386.jpg
# /kaggle/input/classify-leaves/images/18273.jpg
# /kaggle/input/classify-leaves/images/22491.jpg
# /kaggle/input/classify-leaves/images/20313.jpg
# /kaggle/input/classify-leaves/images/9562.jpg
# /kaggle/input/classify-leaves/images/1840.jpg
# /kaggle/input/classify-leaves/images/24987.jpg
# /kaggle/input/classify-leaves/images/14610.jpg
# /kaggle/input/classify-leaves/images/22444.jpg
# /kaggle/input/classify-leaves/images/23680.jpg
# /kaggle/input/classify-leaves/images/6085.jpg
# /kaggle/input/classify-leaves/images/8691.jpg
# /kaggle/input/classify-leaves/images/25077.jpg
# /kaggle/input/classify-leaves/images/3996.jpg
# /kaggle/input/classify-leaves/images/3574.jpg
# /kaggle/input/classify-leaves/images/20719.jpg
# /kaggle/input/classify-leaves/images/25289.jpg
# /kaggle/input/classify-leaves/images/26793.jpg
# /kaggle/input/classify-leaves/images/26067.jpg
# /kaggle/input/classify-leaves/images/16841.jpg
# /kaggle/input/classify-leaves/images/3207.jpg
# /kaggle/input/classify-leaves/images/12594.jpg
# /kaggle/input/classify-leaves/images/19491.jpg
# /kaggle/input/classify-leaves/images/26465.jpg
# /kaggle/input/classify-leaves/images/9896.jpg
# /kaggle/input/classify-leaves/images/10790.jpg
# /kaggle/input/classify-leaves/images/22877.jpg
# /kaggle/input/classify-leaves/images/11397.jpg
# /kaggle/input/classify-leaves/images/8110.jpg
# /kaggle/input/classify-leaves/images/21095.jpg
# /kaggle/input/classify-leaves/images/9800.jpg
# /kaggle/input/classify-leaves/images/22229.jpg
# /kaggle/input/classify-leaves/images/12112.jpg
# /kaggle/input/classify-leaves/images/10022.jpg
# /kaggle/input/classify-leaves/images/9483.jpg
# /kaggle/input/classify-leaves/images/2580.jpg
# /kaggle/input/classify-leaves/images/7293.jpg
# /kaggle/input/classify-leaves/images/17759.jpg
# /kaggle/input/classify-leaves/images/13005.jpg
# /kaggle/input/classify-leaves/images/5384.jpg
# /kaggle/input/classify-leaves/images/7815.jpg
# /kaggle/input/classify-leaves/images/8739.jpg
# /kaggle/input/classify-leaves/images/3280.jpg
# /kaggle/input/classify-leaves/images/16197.jpg
# /kaggle/input/classify-leaves/images/7012.jpg
# /kaggle/input/classify-leaves/images/17015.jpg
# /kaggle/input/classify-leaves/images/6682.jpg
# /kaggle/input/classify-leaves/images/10058.jpg
# /kaggle/input/classify-leaves/images/6386.jpg
# /kaggle/input/classify-leaves/images/10573.jpg
# /kaggle/input/classify-leaves/images/15706.jpg
# /kaggle/input/classify-leaves/images/19010.jpg
# /kaggle/input/classify-leaves/images/1124.jpg
# /kaggle/input/classify-leaves/images/4472.jpg
# /kaggle/input/classify-leaves/images/7744.jpg
# /kaggle/input/classify-leaves/images/15167.jpg
# /kaggle/input/classify-leaves/images/501.jpg
# /kaggle/input/classify-leaves/images/23049.jpg
# /kaggle/input/classify-leaves/images/16500.jpg
# /kaggle/input/classify-leaves/images/5240.jpg
# /kaggle/input/classify-leaves/images/24792.jpg
# /kaggle/input/classify-leaves/images/1395.jpg
# /kaggle/input/classify-leaves/images/19012.jpg
# /kaggle/input/classify-leaves/images/10686.jpg
# /kaggle/input/classify-leaves/images/13467.jpg
# /kaggle/input/classify-leaves/images/12817.jpg
# /kaggle/input/classify-leaves/images/6107.jpg
# /kaggle/input/classify-leaves/images/22070.jpg
# /kaggle/input/classify-leaves/images/20865.jpg
# /kaggle/input/classify-leaves/images/13325.jpg
# /kaggle/input/classify-leaves/images/3823.jpg
# /kaggle/input/classify-leaves/images/20375.jpg
# /kaggle/input/classify-leaves/images/19579.jpg
# /kaggle/input/classify-leaves/images/15674.jpg
# /kaggle/input/classify-leaves/images/14151.jpg
# /kaggle/input/classify-leaves/images/3467.jpg
# /kaggle/input/classify-leaves/images/8131.jpg
# /kaggle/input/classify-leaves/images/6471.jpg
# /kaggle/input/classify-leaves/images/26536.jpg
# /kaggle/input/classify-leaves/images/10157.jpg
# /kaggle/input/classify-leaves/images/2363.jpg
# /kaggle/input/classify-leaves/images/9733.jpg
# /kaggle/input/classify-leaves/images/7489.jpg
# /kaggle/input/classify-leaves/images/5641.jpg
# /kaggle/input/classify-leaves/images/25097.jpg
# /kaggle/input/classify-leaves/images/18087.jpg
# /kaggle/input/classify-leaves/images/3562.jpg
# /kaggle/input/classify-leaves/images/17988.jpg
# /kaggle/input/classify-leaves/images/915.jpg
# /kaggle/input/classify-leaves/images/815.jpg
# /kaggle/input/classify-leaves/images/16389.jpg
# /kaggle/input/classify-leaves/images/9634.jpg
# /kaggle/input/classify-leaves/images/5266.jpg
# /kaggle/input/classify-leaves/images/14649.jpg
# /kaggle/input/classify-leaves/images/6509.jpg
# /kaggle/input/classify-leaves/images/20070.jpg
# /kaggle/input/classify-leaves/images/8648.jpg
# /kaggle/input/classify-leaves/images/20371.jpg
# /kaggle/input/classify-leaves/images/21859.jpg
# /kaggle/input/classify-leaves/images/21644.jpg
# /kaggle/input/classify-leaves/images/11550.jpg
# /kaggle/input/classify-leaves/images/11784.jpg
# /kaggle/input/classify-leaves/images/16445.jpg
# /kaggle/input/classify-leaves/images/16241.jpg
# /kaggle/input/classify-leaves/images/3654.jpg
# /kaggle/input/classify-leaves/images/9148.jpg
# /kaggle/input/classify-leaves/images/21577.jpg
# /kaggle/input/classify-leaves/images/9464.jpg
# /kaggle/input/classify-leaves/images/4256.jpg
# /kaggle/input/classify-leaves/images/18244.jpg
# /kaggle/input/classify-leaves/images/6574.jpg
# /kaggle/input/classify-leaves/images/17282.jpg
# /kaggle/input/classify-leaves/images/23527.jpg
# /kaggle/input/classify-leaves/images/11514.jpg
# /kaggle/input/classify-leaves/images/10470.jpg
# /kaggle/input/classify-leaves/images/23859.jpg
# /kaggle/input/classify-leaves/images/4305.jpg
# /kaggle/input/classify-leaves/images/760.jpg
# /kaggle/input/classify-leaves/images/342.jpg
# /kaggle/input/classify-leaves/images/21761.jpg
# /kaggle/input/classify-leaves/images/26508.jpg
# /kaggle/input/classify-leaves/images/8554.jpg
# /kaggle/input/classify-leaves/images/11756.jpg
# /kaggle/input/classify-leaves/images/11552.jpg
# /kaggle/input/classify-leaves/images/5192.jpg
# /kaggle/input/classify-leaves/images/21128.jpg
# /kaggle/input/classify-leaves/images/26106.jpg
# /kaggle/input/classify-leaves/images/1459.jpg
# /kaggle/input/classify-leaves/images/23461.jpg
# /kaggle/input/classify-leaves/images/26151.jpg
# /kaggle/input/classify-leaves/images/10126.jpg
# /kaggle/input/classify-leaves/images/8130.jpg
# /kaggle/input/classify-leaves/images/14020.jpg
# /kaggle/input/classify-leaves/images/8440.jpg
# /kaggle/input/classify-leaves/images/2704.jpg
# ...
# /kaggle/input/classify-leaves/images/1923.jpg
# /kaggle/input/classify-leaves/images/1021.jpg
# /kaggle/input/classify-leaves/images/12454.jpg
# /kaggle/input/classify-leaves/images/7239.jpg
# /kaggle/input/classify-leaves/images/136.jpg
# /kaggle/input/classify-leaves/images/24634.jpg
# /kaggle/input/classify-leaves/images/15832.jpg
# /kaggle/input/classify-leaves/images/5366.jpg
# /kaggle/input/classify-leaves/images/10045.jpg
# /kaggle/input/classify-leaves/images/1015.jpg
# /kaggle/input/classify-leaves/images/4203.jpg
# /kaggle/input/classify-leaves/images/25176.jpg
# /kaggle/input/classify-leaves/images/25757.jpg
# /kaggle/input/classify-leaves/images/21103.jpg
# /kaggle/input/classify-leaves/images/14451.jpg
# /kaggle/input/classify-leaves/images/20921.jpg
# /kaggle/input/classify-leaves/images/5696.jpg
# /kaggle/input/classify-leaves/images/22236.jpg
# /kaggle/input/classify-leaves/images/17360.jpg
# /kaggle/input/classify-leaves/images/15184.jpg
# /kaggle/input/classify-leaves/images/12182.jpg
# /kaggle/input/classify-leaves/images/1538.jpg
# /kaggle/input/classify-leaves/images/13320.jpg
# /kaggle/input/classify-leaves/images/3706.jpg
# /kaggle/input/classify-leaves/images/1252.jpg
# /kaggle/input/classify-leaves/images/20022.jpg
# /kaggle/input/classify-leaves/images/10390.jpg
# /kaggle/input/classify-leaves/images/1861.jpg
# /kaggle/input/classify-leaves/images/4928.jpg
# /kaggle/input/classify-leaves/images/14501.jpg
# /kaggle/input/classify-leaves/images/25664.jpg
# /kaggle/input/classify-leaves/images/15115.jpg
# /kaggle/input/classify-leaves/images/1849.jpg
# /kaggle/input/classify-leaves/images/14409.jpg
# /kaggle/input/classify-leaves/images/22507.jpg
# /kaggle/input/classify-leaves/images/14815.jpg
# /kaggle/input/classify-leaves/images/24009.jpg
# /kaggle/input/classify-leaves/images/9050.jpg
# /kaggle/input/classify-leaves/images/8764.jpg
# /kaggle/input/classify-leaves/images/16211.jpg
# /kaggle/input/classify-leaves/images/2212.jpg
# /kaggle/input/classify-leaves/images/2461.jpg
# /kaggle/input/classify-leaves/images/1236.jpg
# /kaggle/input/classify-leaves/images/5051.jpg
# /kaggle/input/classify-leaves/images/26889.jpg
# /kaggle/input/classify-leaves/images/3536.jpg
# /kaggle/input/classify-leaves/images/26840.jpg
# /kaggle/input/classify-leaves/images/19922.jpg
# /kaggle/input/classify-leaves/images/16707.jpg
# /kaggle/input/classify-leaves/images/11866.jpg
# /kaggle/input/classify-leaves/images/22749.jpg
# /kaggle/input/classify-leaves/images/5708.jpg
# /kaggle/input/classify-leaves/images/2151.jpg
# /kaggle/input/classify-leaves/images/21703.jpg
# /kaggle/input/classify-leaves/images/20549.jpg
# /kaggle/input/classify-leaves/images/12212.jpg
# /kaggle/input/classify-leaves/images/18008.jpg
# /kaggle/input/classify-leaves/images/5414.jpg
# /kaggle/input/classify-leaves/images/3911.jpg
# /kaggle/input/classify-leaves/images/8146.jpg
# /kaggle/input/classify-leaves/images/13971.jpg
# /kaggle/input/classify-leaves/images/15759.jpg
# /kaggle/input/classify-leaves/images/16929.jpg
# /kaggle/input/classify-leaves/images/17774.jpg
# /kaggle/input/classify-leaves/images/7055.jpg
# /kaggle/input/classify-leaves/images/1976.jpg
# /kaggle/input/classify-leaves/images/18030.jpg
# /kaggle/input/classify-leaves/images/13319.jpg
# /kaggle/input/classify-leaves/images/1515.jpg
# /kaggle/input/classify-leaves/images/21054.jpg
# /kaggle/input/classify-leaves/images/1141.jpg
# /kaggle/input/classify-leaves/images/3737.jpg
# /kaggle/input/classify-leaves/images/18190.jpg
# /kaggle/input/classify-leaves/images/26311.jpg
# /kaggle/input/classify-leaves/images/3496.jpg
# /kaggle/input/classify-leaves/images/24967.jpg
# /kaggle/input/classify-leaves/images/12663.jpg
# /kaggle/input/classify-leaves/images/4335.jpg
# /kaggle/input/classify-leaves/images/4143.jpg
# /kaggle/input/classify-leaves/images/18696.jpg
# /kaggle/input/classify-leaves/images/2861.jpg
# /kaggle/input/classify-leaves/images/21161.jpg
# /kaggle/input/classify-leaves/images/9907.jpg
# /kaggle/input/classify-leaves/images/15637.jpg
# /kaggle/input/classify-leaves/images/6271.jpg
# /kaggle/input/classify-leaves/images/5995.jpg
# /kaggle/input/classify-leaves/images/14670.jpg
# /kaggle/input/classify-leaves/images/16319.jpg
# /kaggle/input/classify-leaves/images/19171.jpg
# /kaggle/input/classify-leaves/images/5798.jpg
# /kaggle/input/classify-leaves/images/12432.jpg
# /kaggle/input/classify-leaves/images/11525.jpg
# /kaggle/input/classify-leaves/images/20832.jpg
# /kaggle/input/classify-leaves/images/2769.jpg
# /kaggle/input/classify-leaves/images/23127.jpg
# /kaggle/input/classify-leaves/images/11414.jpg
# /kaggle/input/classify-leaves/images/24489.jpg
# /kaggle/input/classify-leaves/images/23770.jpg
# /kaggle/input/classify-leaves/images/18439.jpg
# /kaggle/input/classify-leaves/images/2710.jpg
# /kaggle/input/classify-leaves/images/19967.jpg
# /kaggle/input/classify-leaves/images/20654.jpg
# /kaggle/input/classify-leaves/images/24983.jpg
# /kaggle/input/classify-leaves/images/10842.jpg
# /kaggle/input/classify-leaves/images/3774.jpg
# /kaggle/input/classify-leaves/images/16475.jpg
# /kaggle/input/classify-leaves/images/14079.jpg
# /kaggle/input/classify-leaves/images/24156.jpg
# /kaggle/input/classify-leaves/images/17296.jpg
# /kaggle/input/classify-leaves/images/13327.jpg
# /kaggle/input/classify-leaves/images/7807.jpg
# /kaggle/input/classify-leaves/images/9240.jpg
# /kaggle/input/classify-leaves/images/23299.jpg
# /kaggle/input/classify-leaves/images/3882.jpg
# /kaggle/input/classify-leaves/images/7383.jpg
# /kaggle/input/classify-leaves/images/2092.jpg
# /kaggle/input/classify-leaves/images/4680.jpg
# /kaggle/input/classify-leaves/images/13136.jpg
# /kaggle/input/classify-leaves/images/7836.jpg
# /kaggle/input/classify-leaves/images/23380.jpg
# /kaggle/input/classify-leaves/images/21096.jpg
# /kaggle/input/classify-leaves/images/18490.jpg
# /kaggle/input/classify-leaves/images/14711.jpg
# /kaggle/input/classify-leaves/images/17337.jpg
# /kaggle/input/classify-leaves/images/9255.jpg
# /kaggle/input/classify-leaves/images/3349.jpg
# /kaggle/input/classify-leaves/images/19607.jpg
# /kaggle/input/classify-leaves/images/12412.jpg
# /kaggle/input/classify-leaves/images/24179.jpg
# /kaggle/input/classify-leaves/images/17180.jpg
# /kaggle/input/classify-leaves/images/8639.jpg
# /kaggle/input/classify-leaves/images/7723.jpg
# /kaggle/input/classify-leaves/images/7607.jpg
# /kaggle/input/classify-leaves/images/9389.jpg
# /kaggle/input/classify-leaves/images/7868.jpg
# /kaggle/input/classify-leaves/images/16801.jpg
# /kaggle/input/classify-leaves/images/13510.jpg
# /kaggle/input/classify-leaves/images/8589.jpg
# /kaggle/input/classify-leaves/images/10898.jpg
# /kaggle/input/classify-leaves/images/13576.jpg
# /kaggle/input/classify-leaves/images/17051.jpg
# /kaggle/input/classify-leaves/images/2884.jpg
# /kaggle/input/classify-leaves/images/17747.jpg
# /kaggle/input/classify-leaves/images/16258.jpg
# /kaggle/input/classify-leaves/images/26422.jpg
# /kaggle/input/classify-leaves/images/15685.jpg
# /kaggle/input/classify-leaves/images/15914.jpg
# /kaggle/input/classify-leaves/images/11307.jpg
# /kaggle/input/classify-leaves/images/3695.jpg
# /kaggle/input/classify-leaves/images/11532.jpg
# /kaggle/input/classify-leaves/images/15981.jpg
# /kaggle/input/classify-leaves/images/21293.jpg
# /kaggle/input/classify-leaves/images/15771.jpg
# /kaggle/input/classify-leaves/images/21395.jpg
# /kaggle/input/classify-leaves/images/26535.jpg
# /kaggle/input/classify-leaves/images/925.jpg
# /kaggle/input/classify-leaves/images/16815.jpg
# /kaggle/input/classify-leaves/images/27090.jpg
# /kaggle/input/classify-leaves/images/2969.jpg
# /kaggle/input/classify-leaves/images/4466.jpg
# /kaggle/input/classify-leaves/images/22503.jpg
# /kaggle/input/classify-leaves/images/20402.jpg
# /kaggle/input/classify-leaves/images/1903.jpg
# /kaggle/input/classify-leaves/images/5385.jpg
# /kaggle/input/classify-leaves/images/8692.jpg
# /kaggle/input/classify-leaves/images/6853.jpg
# /kaggle/input/classify-leaves/images/21687.jpg
# /kaggle/input/classify-leaves/images/8606.jpg
# /kaggle/input/classify-leaves/images/18873.jpg
# /kaggle/input/classify-leaves/images/2689.jpg
# /kaggle/input/classify-leaves/images/7413.jpg
# /kaggle/input/classify-leaves/images/18390.jpg
# /kaggle/input/classify-leaves/images/9517.jpg
# /kaggle/input/classify-leaves/images/21684.jpg
# /kaggle/input/classify-leaves/images/23573.jpg
# /kaggle/input/classify-leaves/images/14003.jpg
# /kaggle/input/classify-leaves/images/20060.jpg
# /kaggle/input/classify-leaves/images/3613.jpg
# /kaggle/input/classify-leaves/images/5972.jpg
# /kaggle/input/classify-leaves/images/4678.jpg
# /kaggle/input/classify-leaves/images/13286.jpg
# /kaggle/input/classify-leaves/images/5252.jpg
# /kaggle/input/classify-leaves/images/5766.jpg
# /kaggle/input/classify-leaves/images/17224.jpg
# /kaggle/input/classify-leaves/images/12391.jpg
# /kaggle/input/classify-leaves/images/12209.jpg
# /kaggle/input/classify-leaves/images/15176.jpg
# /kaggle/input/classify-leaves/images/9295.jpg
# /kaggle/input/classify-leaves/images/8856.jpg
# /kaggle/input/classify-leaves/images/9891.jpg
# /kaggle/input/classify-leaves/images/9175.jpg
# /kaggle/input/classify-leaves/images/10535.jpg
# /kaggle/input/classify-leaves/images/3495.jpg
# /kaggle/input/classify-leaves/images/16361.jpg
# /kaggle/input/classify-leaves/images/20797.jpg
# /kaggle/input/classify-leaves/images/454.jpg
# /kaggle/input/classify-leaves/images/22054.jpg
# /kaggle/input/classify-leaves/images/15645.jpg
# /kaggle/input/classify-leaves/images/5723.jpg
# /kaggle/input/classify-leaves/images/2607.jpg
# /kaggle/input/classify-leaves/images/19464.jpg
# /kaggle/input/classify-leaves/images/605.jpg
# /kaggle/input/classify-leaves/images/754.jpg
# /kaggle/input/classify-leaves/images/15787.jpg
# /kaggle/input/classify-leaves/images/23518.jpg
# /kaggle/input/classify-leaves/images/14480.jpg
# /kaggle/input/classify-leaves/images/18836.jpg
# /kaggle/input/classify-leaves/images/24209.jpg
# /kaggle/input/classify-leaves/images/19621.jpg
# /kaggle/input/classify-leaves/images/9734.jpg
# /kaggle/input/classify-leaves/images/25567.jpg
# /kaggle/input/classify-leaves/images/753.jpg
# /kaggle/input/classify-leaves/images/13140.jpg
# /kaggle/input/classify-leaves/images/364.jpg
# /kaggle/input/classify-leaves/images/18505.jpg
# /kaggle/input/classify-leaves/images/9338.jpg
# /kaggle/input/classify-leaves/images/2691.jpg
# /kaggle/input/classify-leaves/images/90.jpg
# /kaggle/input/classify-leaves/images/26062.jpg
# /kaggle/input/classify-leaves/images/5515.jpg
# /kaggle/input/classify-leaves/images/599.jpg
# /kaggle/input/classify-leaves/images/25.jpg
# /kaggle/input/classify-leaves/images/24295.jpg
# /kaggle/input/classify-leaves/images/20342.jpg
# /kaggle/input/classify-leaves/images/7987.jpg
# /kaggle/input/classify-leaves/images/24925.jpg
# /kaggle/input/classify-leaves/images/4490.jpg
# /kaggle/input/classify-leaves/images/18277.jpg
# /kaggle/input/classify-leaves/images/3267.jpg
# /kaggle/input/classify-leaves/images/11519.jpg
# /kaggle/input/classify-leaves/images/24159.jpg
# /kaggle/input/classify-leaves/images/26942.jpg
# /kaggle/input/classify-leaves/images/12784.jpg
# /kaggle/input/classify-leaves/images/8481.jpg
# /kaggle/input/classify-leaves/images/1201.jpg
# /kaggle/input/classify-leaves/images/8217.jpg
# /kaggle/input/classify-leaves/images/3120.jpg
# /kaggle/input/classify-leaves/images/17867.jpg
# /kaggle/input/classify-leaves/images/11783.jpg
# /kaggle/input/classify-leaves/images/7878.jpg
# /kaggle/input/classify-leaves/images/25605.jpg
# /kaggle/input/classify-leaves/images/2867.jpg
# /kaggle/input/classify-leaves/images/22473.jpg
# /kaggle/input/classify-leaves/images/7370.jpg
# /kaggle/input/classify-leaves/images/5272.jpg
# /kaggle/input/classify-leaves/images/7156.jpg
# /kaggle/input/classify-leaves/images/22328.jpg
# /kaggle/input/classify-leaves/images/1801.jpg
# /kaggle/input/classify-leaves/images/3000.jpg
# /kaggle/input/classify-leaves/images/16441.jpg
# /kaggle/input/classify-leaves/images/15562.jpg
# /kaggle/input/classify-leaves/images/8193.jpg
# /kaggle/input/classify-leaves/images/6785.jpg
# /kaggle/input/classify-leaves/images/16380.jpg
# /kaggle/input/classify-leaves/images/11091.jpg
# /kaggle/input/classify-leaves/images/7105.jpg
# /kaggle/input/classify-leaves/images/15694.jpg
# /kaggle/input/classify-leaves/images/6710.jpg
# /kaggle/input/classify-leaves/images/4421.jpg
# /kaggle/input/classify-leaves/images/21981.jpg
# /kaggle/input/classify-leaves/images/14936.jpg
# /kaggle/input/classify-leaves/images/11884.jpg
# /kaggle/input/classify-leaves/images/8806.jpg
# /kaggle/input/classify-leaves/images/14667.jpg
# /kaggle/input/classify-leaves/images/5894.jpg
# /kaggle/input/classify-leaves/images/25882.jpg
# /kaggle/input/classify-leaves/images/1979.jpg
# /kaggle/input/classify-leaves/images/13307.jpg
# /kaggle/input/classify-leaves/images/10802.jpg
# /kaggle/input/classify-leaves/images/19736.jpg
# /kaggle/input/classify-leaves/images/21691.jpg
# /kaggle/input/classify-leaves/images/3059.jpg
# /kaggle/input/classify-leaves/images/7842.jpg
# /kaggle/input/classify-leaves/images/3410.jpg
# /kaggle/input/classify-leaves/images/2085.jpg
# /kaggle/input/classify-leaves/images/13900.jpg
# /kaggle/input/classify-leaves/images/18740.jpg
# /kaggle/input/classify-leaves/images/16373.jpg
# /kaggle/input/classify-leaves/images/16494.jpg
# /kaggle/input/classify-leaves/images/10371.jpg
# /kaggle/input/classify-leaves/images/22668.jpg
# /kaggle/input/classify-leaves/images/9843.jpg
# /kaggle/input/classify-leaves/images/26657.jpg
# /kaggle/input/classify-leaves/images/23154.jpg
# /kaggle/input/classify-leaves/images/10129.jpg
# /kaggle/input/classify-leaves/images/10226.jpg
# /kaggle/input/classify-leaves/images/4968.jpg
# /kaggle/input/classify-leaves/images/7318.jpg
# /kaggle/input/classify-leaves/images/23544.jpg
# /kaggle/input/classify-leaves/images/18528.jpg
# /kaggle/input/classify-leaves/images/21317.jpg
# /kaggle/input/classify-leaves/images/16201.jpg
# /kaggle/input/classify-leaves/images/10974.jpg
# /kaggle/input/classify-leaves/images/17442.jpg
# /kaggle/input/classify-leaves/images/18861.jpg
# /kaggle/input/classify-leaves/images/5922.jpg
# /kaggle/input/classify-leaves/images/24492.jpg
# /kaggle/input/classify-leaves/images/25690.jpg
# /kaggle/input/classify-leaves/images/147.jpg
# /kaggle/input/classify-leaves/images/9201.jpg
# /kaggle/input/classify-leaves/images/5005.jpg
# /kaggle/input/classify-leaves/images/8281.jpg
# /kaggle/input/classify-leaves/images/15816.jpg
# /kaggle/input/classify-leaves/images/23416.jpg
# /kaggle/input/classify-leaves/images/13114.jpg
# /kaggle/input/classify-leaves/images/22159.jpg
# /kaggle/input/classify-leaves/images/7473.jpg
# /kaggle/input/classify-leaves/images/25804.jpg
# /kaggle/input/classify-leaves/images/13877.jpg
# /kaggle/input/classify-leaves/images/5088.jpg
# /kaggle/input/classify-leaves/images/23168.jpg
# /kaggle/input/classify-leaves/images/5254.jpg
# /kaggle/input/classify-leaves/images/11205.jpg
# /kaggle/input/classify-leaves/images/23863.jpg
# /kaggle/input/classify-leaves/images/7138.jpg
# /kaggle/input/classify-leaves/images/17953.jpg
# /kaggle/input/classify-leaves/images/9508.jpg
# /kaggle/input/classify-leaves/images/19101.jpg
# /kaggle/input/classify-leaves/images/22744.jpg
# /kaggle/input/classify-leaves/images/921.jpg
# /kaggle/input/classify-leaves/images/4463.jpg
# /kaggle/input/classify-leaves/images/7674.jpg
# /kaggle/input/classify-leaves/images/20038.jpg
# /kaggle/input/classify-leaves/images/3950.jpg
# /kaggle/input/classify-leaves/images/8684.jpg
# /kaggle/input/classify-leaves/images/20287.jpg
# /kaggle/input/classify-leaves/images/5303.jpg
# /kaggle/input/classify-leaves/images/728.jpg
# /kaggle/input/classify-leaves/images/23874.jpg
# /kaggle/input/classify-leaves/images/21432.jpg
# /kaggle/input/classify-leaves/images/1656.jpg
# /kaggle/input/classify-leaves/images/8658.jpg
# /kaggle/input/classify-leaves/images/6119.jpg
# /kaggle/input/classify-leaves/images/8152.jpg
# /kaggle/input/classify-leaves/images/18973.jpg
# /kaggle/input/classify-leaves/images/3361.jpg
# /kaggle/input/classify-leaves/images/22292.jpg
# /kaggle/input/classify-leaves/images/16986.jpg
# /kaggle/input/classify-leaves/images/21885.jpg
# /kaggle/input/classify-leaves/images/2599.jpg
# /kaggle/input/classify-leaves/images/10035.jpg
# /kaggle/input/classify-leaves/images/11590.jpg
# /kaggle/input/classify-leaves/images/23579.jpg

# %%
# !pip install d2l
# Out:
# Requirement already satisfied: d2l in /opt/conda/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: jupyter==1.0.0 in /opt/conda/lib/python3.10/site-packages (from d2l) (1.0.0)
# Requirement already satisfied: numpy==1.23.5 in /opt/conda/lib/python3.10/site-packages (from d2l) (1.23.5)
# Requirement already satisfied: matplotlib==3.7.2 in /opt/conda/lib/python3.10/site-packages (from d2l) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /opt/conda/lib/python3.10/site-packages (from d2l) (0.1.6)
# Requirement already satisfied: requests==2.31.0 in /opt/conda/lib/python3.10/site-packages (from d2l) (2.31.0)
# Requirement already satisfied: pandas==2.0.3 in /opt/conda/lib/python3.10/site-packages (from d2l) (2.0.3)
# Requirement already satisfied: scipy==1.10.1 in /opt/conda/lib/python3.10/site-packages (from d2l) (1.10.1)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.5.4)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (5.4.4)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.4.5)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.23.3)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (2.8.2)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.10/site-packages (from matplotlib-inline==0.1.6->d2l) (5.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests==2.31.0->d2l) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests==2.31.0->d2l) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests==2.31.0->d2l) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests==2.31.0->d2l) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.14.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.3.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.5.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.9.3)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.3.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.0.7)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (3.0.38)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (2.15.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: nbformat>=4.4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.9.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.4)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.12.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (2.1.3)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (1.0.0)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.4.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.18.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.5)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (0.2.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (4.17.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l) (0.2.6)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0->d2l) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (0.4.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (6.5.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (1.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0->d2l) (1.15.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (1.1.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0->d2l) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (6.0)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0->d2l) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (2.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter==1.0.0->d2l) (1.2.3)

# %%
import torch
import torch.nn as nn
import d2l
import torchvision
import torch.nn.functional as F

# %%
# 图像增广
transform_train = torchvision.transforms.Compose([
	torchvision.transforms.Resize(250),
	torchvision.transforms.RandomResizedCrop(224, scale=(0.6, 1.0), ratio=(1.0, 1.0)),
	torchvision.transforms.RandomHorizontalFlip(),
	torchvision.transforms.ToTensor(),
	torchvision.transforms.Normalize([0.4914, 0.4822, 0.4465],
                                     [0.2023, 0.1994, 0.2010])])
# 只对图像进行标准化，消除评估结果中的随机性                                     
transform_test = torchvision.transforms.Compose([
	torchvision.transforms.ToTensor(),
	torchvision.transforms.Normalize([0.4914, 0.4822, 0.4465],
                                     [0.2023, 0.1994, 0.2010])])

# %%
# 定义Dataset
import pandas as pd
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import torchvision.transforms as transforms

class CustomDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.data = pd.read_csv(csv_file) 
        self.root_dir = root_dir
        self.transform = transform
        if 'label' in self.data.columns:
            label_encoder = LabelEncoder()
            self.labels = label_encoder.fit_transform(self.data['label'])
            self.classes = {x : y for x, y in zip(self.labels, self.data['label'])}
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.data.iloc[idx, 0])
        image = Image.open(img_name)
        if self.transform is not None:
            image = self.transform(image)
        
        if 'label' in self.data.columns:
            label = F.one_hot(torch.tensor(self.labels[idx]), num_classes=self.data['label'].nunique()).float()
            return image, label
        else:
            return image, -1

# %%
# d2l.argmax, d2l.astype, d2l.reduce_sum, d2l.accracy

argmax = lambda x, *args, **kwargs: x.argmax(*args, **kwargs)
astype = lambda x, *args, **kwargs: x.type(*args, **kwargs)
reduce_sum = lambda x, *args, **kwargs: x.sum(*args, **kwargs)

def accuracy(y_hat, y):
    """
    计算判断正确的数量
    """
    if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:
        y_hat = argmax(y_hat, axis=1)
    cmp = astype(y_hat, y.dtype) == y
    return float(reduce_sum(astype(cmp, y.dtype)))

# %%
# d2l.Accumulator
class Accumulator:
    """
    长为n的list，每次add对应位置上相加
    """
    def __init__(self, n):
        self.data = [0.0] * n
    
    def add(self, *args):
        self.data = [a + float(b) for a, b in zip(self.data, args)]
    
    def reset(self):
        self.data = [0, 0] * len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx]

def try_gpu(i=0):
    if torch.cuda.device_count() >= i+1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')

# %%
# 定义参数和超参数训练
batch_size = 1
lr, num_epochs = 1, 10

# %%
# 加载数据
sample = '/kaggle/input/classify-leaves/sample_submission.csv'
ts_path = "/kaggle/input/classify-leaves/test.csv"
tr_path = "/kaggle/input/classify-leaves/train.csv"
image_path = '/kaggle/input/classify-leaves'

dataset = CustomDataset(csv_file = tr_path, root_dir = image_path, transform=transform_train)
train_size = int(0.8 * len(dataset))
valid_size = len(dataset) - train_size
tr_dataset, te_dataset = torch.utils.data.random_split(dataset, [train_size, valid_size])

tr_dataloader = DataLoader(tr_dataset, batch_size, shuffle=True)
ts_dataloader = DataLoader(te_dataset, batch_size, shuffle=False)

# %%
dataset.classes
# Out:
# {78: 'maclura_pomifera',
#  174: 'ulmus_rubra',
#  28: 'broussonettia_papyrifera',
#  130: 'prunus_virginiana',
#  10: 'acer_rubrum',
#  58: 'cryptomeria_japonica',
#  160: 'staphylea_trifolia',
#  22: 'asimina_triloba',
#  59: 'diospyros_virginiana',
#  165: 'tilia_cordata',
#  173: 'ulmus_pumila',
#  145: 'quercus_muehlenbergii',
#  71: 'juglans_cinerea',
#  44: 'cercis_canadensis',
#  133: 'ptelea_trifoliata',
#  6: 'acer_palmatum',
#  37: 'catalpa_speciosa',
#  0: 'abies_concolor',
#  60: 'eucommia_ulmoides',
#  144: 'quercus_montana',
#  74: 'koelreuteria_paniculata',
#  77: 'liriodendron_tulipifera',
#  162: 'styrax_japonica',
#  90: 'malus_pumila',
#  126: 'prunus_sargentii',
#  52: 'cornus_mas',
#  85: 'magnolia_virginiana',
#  95: 'ostrya_virginiana',
#  79: 'magnolia_acuminata',
#  70: 'ilex_opaca',
#  5: 'acer_negundo',
#  64: 'fraxinus_nigra',
#  134: 'pyrus_calleryana',
#  99: 'picea_abies',
#  48: 'chionanthus_virginicus',
#  30: 'carpinus_caroliniana',
#  175: 'zelkova_serrata',
#  16: 'aesculus_pavi',
#  163: 'taxodium_distichum',
#  34: 'carya_tomentosa',
#  101: 'picea_pungens',
#  32: 'carya_glabra',
#  141: 'quercus_macrocarpa',
#  31: 'carya_cordiformis',
#  36: 'catalpa_bignonioides',
#  168: 'tsuga_canadensis',
#  124: 'populus_tremuloides',
#  80: 'magnolia_denudata',
#  57: 'crataegus_viridis',
#  122: 'populus_deltoides',
#  169: 'ulmus_americana',
#  102: 'pinus_bungeana',
#  50: 'cornus_florida',
#  104: 'pinus_densiflora',
#  92: 'morus_alba',
#  152: 'quercus_velutina',
#  109: 'pinus_parviflora',
#  156: 'salix_caroliniana',
#  121: 'platanus_occidentalis',
#  12: 'acer_saccharum',
#  106: 'pinus_flexilis',
#  67: 'gleditsia_triacanthos',
#  136: 'quercus_alba',
#  129: 'prunus_subhirtella',
#  132: 'pseudolarix_amabilis',
#  161: 'stewartia_pseudocamellia',
#  151: 'quercus_stellata',
#  113: 'pinus_rigida',
#  158: 'salix_nigra',
#  135: 'quercus_acutissima',
#  118: 'pinus_virginiana',
#  45: 'chamaecyparis_pisifera',
#  143: 'quercus_michauxii',
#  125: 'prunus_pensylvanica',
#  20: 'amelanchier_canadensis',
#  76: 'liquidambar_styraciflua',
#  103: 'pinus_cembra',
#  89: 'malus_hupehensis',
#  35: 'castanea_dentata',
#  83: 'magnolia_stellata',
#  47: 'chionanthus_retusus',
#  33: 'carya_ovata',
#  142: 'quercus_marilandica',
#  164: 'tilia_americana',
#  38: 'cedrus_atlantica',
#  171: 'ulmus_parvifolia',
#  94: 'nyssa_sylvatica',
#  153: 'quercus_virginiana',
#  11: 'acer_saccharinum',
#  82: 'magnolia_macrophylla',
#  56: 'crataegus_pruinosa',
#  108: 'pinus_nigra',
#  1: 'abies_nordmanniana',
#  116: 'pinus_taeda',
#  63: 'ficus_carica',
#  110: 'pinus_peucea',
#  123: 'populus_grandidentata',
#  8: 'acer_platanoides',
#  112: 'pinus_resinosa',
#  157: 'salix_matsudana',
#  115: 'pinus_sylvestris',
#  18: 'albizia_julibrissin',
#  155: 'salix_babylonica',
#  105: 'pinus_echinata',
#  84: 'magnolia_tripetala',
#  75: 'larix_decidua',
#  114: 'pinus_strobus',
#  14: 'aesculus_glabra',
#  66: 'ginkgo_biloba',
#  138: 'quercus_cerris',
#  91: 'metasequoia_glyptostroboides',
#  62: 'fagus_grandifolia',
#  146: 'quercus_nigra',
#  72: 'juglans_nigra',
#  107: 'pinus_koraiensis',
#  96: 'oxydendrum_arboreum',
#  93: 'morus_rubra',
#  55: 'crataegus_phaenopyrum',
#  119: 'pinus_wallichiana',
#  166: 'tilia_europaea',
#  24: 'betula_jacqemontii',
#  46: 'chamaecyparis_thyoides',
#  3: 'acer_ginnala',
#  2: 'acer_campestre',
#  111: 'pinus_pungens',
#  88: 'malus_floribunda',
#  100: 'picea_orientalis',
#  21: 'amelanchier_laevis',
#  42: 'celtis_tenuifolia',
#  68: 'gymnocladus_dioicus',
#  137: 'quercus_bicolor',
#  87: 'malus_coronaria',
#  43: 'cercidiphyllum_japonicum',
#  40: 'cedrus_libani',
#  26: 'betula_nigra',
#  7: 'acer_pensylvanicum',
#  120: 'platanus_acerifolia',
#  154: 'robinia_pseudo-acacia',
#  170: 'ulmus_glabra',
#  54: 'crataegus_laevigata',
#  139: 'quercus_coccinea',
#  127: 'prunus_serotina',
#  167: 'tilia_tomentosa',
#  140: 'quercus_imbricaria',
#  49: 'cladrastis_lutea',
#  65: 'fraxinus_pennsylvanica',
#  98: 'phellodendron_amurense',
#  25: 'betula_lenta',
#  149: 'quercus_robur',
#  13: 'aesculus_flava',
#  97: 'paulownia_tomentosa',
#  19: 'amelanchier_arborea',
#  150: 'quercus_shumardii',
#  81: 'magnolia_grandiflora',
#  51: 'cornus_kousa',
#  23: 'betula_alleghaniensis',
#  29: 'carpinus_betulus',
#  15: 'aesculus_hippocastamon',
#  86: 'malus_baccata',
#  9: 'acer_pseudoplatanus',
#  27: 'betula_populifolia',
#  131: 'prunus_yedoensis',
#  69: 'halesia_tetraptera',
#  147: 'quercus_palustris',
#  61: 'evodia_daniellii',
#  172: 'ulmus_procera',
#  128: 'prunus_serrulata',
#  148: 'quercus_phellos',
#  39: 'cedrus_deodara',
#  41: 'celtis_occidentalis',
#  159: 'sassafras_albidum',
#  4: 'acer_griseum',
#  17: 'ailanthus_altissima',
#  117: 'pinus_thunbergii',
#  53: 'crataegus_crus-galli',
#  73: 'juniperus_virginiana'}

# %%
# 定义神经网络结构
net = nn.Sequential(
        nn.Conv2d(3, 6, kernel_size=5, padding=2), nn.Sigmoid(),
        nn.AvgPool2d(kernel_size=2, stride=2),
        nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(),
        nn.AvgPool2d(kernel_size=2, stride=2),
        nn.Flatten(),
        nn.Linear(16 * 54 * 54, 120), nn.Sigmoid(),
        nn.Linear(120, 84), nn.Sigmoid(),
        nn.Linear(84, 176)
      )

# %%
X = torch.rand(size=(1, 3, 224, 224), dtype=torch.float32)
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__, "output shape: \t", X.shape)
# Out:
# Conv2d output shape: 	 torch.Size([1, 6, 224, 224])
# Sigmoid output shape: 	 torch.Size([1, 6, 224, 224])
# AvgPool2d output shape: 	 torch.Size([1, 6, 112, 112])
# Conv2d output shape: 	 torch.Size([1, 16, 108, 108])
# Sigmoid output shape: 	 torch.Size([1, 16, 108, 108])
# AvgPool2d output shape: 	 torch.Size([1, 16, 54, 54])
# Flatten output shape: 	 torch.Size([1, 46656])
# Linear output shape: 	 torch.Size([1, 120])
# Sigmoid output shape: 	 torch.Size([1, 120])
# Linear output shape: 	 torch.Size([1, 84])
# Sigmoid output shape: 	 torch.Size([1, 84])
# Linear output shape: 	 torch.Size([1, 176])

# %%
# 定义评测指标(分类问题的精度)
def evaluate_accuracy_gpu(net, data_iter, device=None):
    print(device)
    if isinstance(net, nn.Module):
        net.eval()
        if not device:
            divice = next(iter(net.parameters())).device
    metric = Accumulator(2)
    net = net.to(device)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# 训练代码
def train_ch6(net, train_iter, test_iter, num_epochs, lr, device):
    print(device)
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    # 应用上述方法初始化net的参数（不同的层有默认的初始化方法）
    net.apply(init_weights)
    
    print("training on ", device)
    net.to(device)
    # 优化器选择
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    # 损失函数
    loss = nn.CrossEntropyLoss(reduction="none")
    
    net = net.to(device)
    for epoch in range(num_epochs):
        metric = Accumulator(3)
        net.train()
        
        for X, y in train_iter:
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], accuracy(y_hat, y), X.shape[0])
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
        if test_iter is not None:    
            test_acc = evaluate_accuracy_gpu(net, test_iter, device)
        
    print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, ')
    if(test_iter is not None):
        print(f'test acc {test_acc:.3f}')
          
# 训练模型
train_ch6(net, tr_dataloader, ts_dataloader, num_epochs, lr, try_gpu())
# Out:
# cuda:0
# training on  cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# loss 5.360, train acc 3.280,
# test acc 0.000

# %%
test_dataset = CustomDataset(csv_file = ts_path, root_dir = image_path, transform=transform_test)

test_dataloader = DataLoader(test_dataset, batch_size, shuffle=False)

# 预测输出

train_ch6(net, ts_dataloader, None, num_epochs, lr, try_gpu())
# Out:
# cuda:0
# training on  cuda:0
# loss 5.377, train acc 2.391,

# %%
ts_df = pd.read_csv(ts_path)
ts_df.head()
# Out:
#               image
# 0  images/18353.jpg
# 1  images/18354.jpg
# 2  images/18355.jpg
# 3  images/18356.jpg
# 4  images/18357.jpg

# %%
preds = []
cnt = 0
for X, _ in test_dataloader:
    y_hat = net(X.to(try_gpu()))
    preds.extend(y_hat.argmax(dim=1).type(torch.int32).cpu().numpy())
    if len(y_hat.argmax(dim=1).type(torch.int32).cpu().numpy()) > 1:
        print('!!!!')
        break
    cnt+=1
print(cnt)
# Out:
# 8800

# %%
sorted_ids = list(range(1, len(test_dataset) + 1))
sorted_ids.sort(key = lambda x : str(x))
print(len(sorted_ids), len(preds))
df = pd.DataFrame({'image': ts_df['image'], 'label': preds})
df['label'] = df['label'].apply(lambda x: dataset.classes[x])
df.to_csv('submission.csv', index=False)
# Out:
# 8800 8800
